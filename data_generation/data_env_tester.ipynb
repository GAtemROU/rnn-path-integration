# %%
from Environment import Environment
env = Environment(3, 10, 20)
env.visualize(True)

# %%
from Agent import Agent
import math
agent = Agent(env, min_speed=1, angle_change_prob=0.7, angle_change_std=math.pi/4)
for _ in range(50):
    agent.step(2)
agent.visualize_path()
print(agent.get_data())
# Out:
# /home/gatemrou/uds/rnn-path-integration/data_generation/Agent.py:55: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   self.data = pd.concat([self.data, pd.DataFrame([[self.steps, self.angle, self.speed, self.x, self.y, collision]], columns=['step', 'angle', 'speed', 'x', 'y', 'collision'])], ignore_index=True)
#    step     angle     speed         x          y collision
# 0     1  3.454518  1.237641 -2.355076  -0.761999     False
# 1     2  4.076667  1.237641 -3.824796  -2.753718     False
# 2     3  4.076667  1.237641 -5.294516  -4.745437     False
# 3     4  4.076667  1.250193 -6.779142  -6.757355     False
# 4     5  4.618727  1.250193 -7.012990  -9.246782     False
# 5     6  4.721415  1.250193 -6.990421 -11.747066     False
# ...
