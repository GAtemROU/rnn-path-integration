# %%
from data_generation.Environment import Environment
env = Environment(4, 1, 2)
env.visualize(True)

# %%
from data_generation.Agent import Agent

agent = Agent(env, kappa=10)
for _ in range(100):
    agent.step(1)
print(agent.resample_counter)
agent.visualize_path()
agent.get_data()
# Out:
# 79
#      step  direction     speed         x         y  collision
# 0       0   0.000000  0.000000  0.000000  0.000000      False
# 1       1   0.179616  0.310000  0.061003  0.011076      False
# 2       2  -0.170557  0.310000  0.122103  0.000553      False
# 3       3  -0.130710  0.310000  0.183574 -0.007528      False
# 4       4  -0.266898  0.310000  0.243379 -0.023880      False
# ..    ...        ...       ...       ...       ...        ...
# 96     96  -7.670504  0.342482  0.574976  0.127206      False
# 97     97  -7.564620  0.342482  0.594521  0.061557      False
# 98     98  -7.947869  0.342482  0.588100 -0.006638      False
# 99     99  -7.774343  0.342482  0.593549 -0.074917      False
# 100   100  -8.272185  0.342482  0.565731 -0.137511      False
#
# [101 rows x 6 columns]

# %%
from data_generation.DataGenerator import DataGenerator
data_gen = DataGenerator(n_agents=10, n_environments=10, n_runs=1, min_steps=100, max_steps=1000, seed=42)
data = data_gen.generate_data()
data
# Out:
# Generating data: 100%|██████████| 100/100 [00:19<00:00,  5.20it/s]
#        step     angle     speed          x         y  collision  agent_id  \
# 0         1  0.688946  0.352944   0.272444  0.224375      False         0
# 1         2  0.010832  0.732854   1.005255  0.232313      False         0
# 2         3  0.010832  0.732854   1.738066  0.240251      False         0
# 3         4  3.608276  0.732854   1.083579 -0.089480      False         0
# 4         5  2.675034  0.732854   0.429051  0.240170      False         0
# ...     ...       ...       ...        ...       ...        ...       ...
# 56989   778  1.006342  1.199191   7.509919  1.653555      False         9
# 56990   779  1.006342  1.199191   8.151432  2.666728      False         9
# 56991   780  1.006342  1.199191   8.792946  3.679901      False         9
# 56992   781  1.006342  1.199191   9.434460  4.693074      False         9
# 56993   782  1.006342  1.386711  10.176288  5.864680      False         9
#
#                                             agent_params  environment_id  \
# 0      {"min_speed": 0.3197133992289419, "max_speed":...               0
# 1      {"min_speed": 0.3197133992289419, "max_speed":...               0
# 2      {"min_speed": 0.3197133992289419, "max_speed":...               0
# 3      {"min_speed": 0.3197133992289419, "max_speed":...               0
# 4      {"min_speed": 0.3197133992289419, "max_speed":...               0
# ...                                                  ...             ...
# 56989  {"min_speed": 0.32401769262329677, "max_speed"...               9
# 56990  {"min_speed": 0.32401769262329677, "max_speed"...               9
# 56991  {"min_speed": 0.32401769262329677, "max_speed"...               9
# 56992  {"min_speed": 0.32401769262329677, "max_speed"...               9
# 56993  {"min_speed": 0.32401769262329677, "max_speed"...               9
#
#                                       environment_params  run_id
# 0      {"num_corners": 8, "min_radius": 10, "max_radi...       0
# 1      {"num_corners": 8, "min_radius": 10, "max_radi...       0
# 2      {"num_corners": 8, "min_radius": 10, "max_radi...       0
# 3      {"num_corners": 8, "min_radius": 10, "max_radi...       0
# 4      {"num_corners": 8, "min_radius": 10, "max_radi...       0
# ...                                                  ...     ...
# 56989  {"num_corners": 8, "min_radius": 9, "max_radiu...       0
# 56990  {"num_corners": 8, "min_radius": 9, "max_radiu...       0
# 56991  {"num_corners": 8, "min_radius": 9, "max_radiu...       0
# 56992  {"num_corners": 8, "min_radius": 9, "max_radiu...       0
# 56993  {"num_corners": 8, "min_radius": 9, "max_radiu...       0
#
# [56994 rows x 11 columns]
